# %%
import pandas as pd
import re
import os
import time

# %%
import cirpy

# %%
# reading S3 is chellenging, due to a format issue of the suppl.
# manually add them
roodt = [
   "Octanal", "1-Octanol/Octanol/Isooctanol", "1-Hexanol", 
    "2-ethyl-", "Heptanal", "2-Butenal", "(E)-", "7-Octen-2-ol", 
    "2,6-dimethyl-/Dihydromyrcenol", "Limonene", "Phenol", 
    "Benzyl alcohol", "Acetic acid/Ethanoic acid", "Hexanal", "Nonanal",
    "Decanal", "5-Hepten-2-one", "6-methyl-", 
    "6-Methyl-3,5-heptadiene-2-one", 
    "Geranylacetone/6,10-Dimethylundeca-5,9-dien-2-one", 
    "Dodecanoic acid", "Tetradecanoic acid/Myristic Acid", 
    "Pentadecanoic acid", "Heptadecanoic acid", "9,12-Octadecadienoic acid (Z,Z)-", 
    "2-Undecanone", "1-Nonanol", "Butyrolactone", 
    "Benzenemethanol", "α,α-dimethyl-", "Octanoic acid", 
    "Propanoic acid", "Butanoic acid", "Hexanoic acid", 
    "Heptanoic acid", "Nonanoic acid", "Decanoic acid", 
    "Tridecanoic acid", "Hexadecanoic acid/n-hexadecanoic acid", 
    "Octadecanoic acid", "Butanoic acid, 3-methyl-/Isovaleric acid", 
    "Hexanoic acid", "2-ethyl-", "2-Octenal", "(E)-", "2-Nonenal", "(E)-", 
    "2-Decenal", "(E)-2-Undecenal", "Furfural/2-Furancarboxyaldehyde", 
    "2-Furancarboxaldehyde", "5-methyl-", "2-Heptanone 2-Octanone", 
    "2-Nonanone", "2-Decanone", "2-Dodecanone", "2-Tridecanone", 
    "2-Pentadecanone", "2-Hexadecanone",
    "Acetophenone/1-phenyl-ethanone", "1-Hydroxy-2-butanone", 
    "Furyl hydroxymethyl ketone", "4H-Pyran-4-one",
    "2,3-dihydro-3,5-dihydroxy-6-methyl-", "Ethanone", 
    "1-(2-furanyl)-", "Ethanone", "1-(4-methylphenyl)-", "2-Undecanone",
    "6,10-dimethyl-", "2,3-Pentanedione", "Cyclopentanone", 
    "2-Cyclopenten-1-one", "Cyclopent-4-ene-1,3-dione", 
    "2-Cyclopenten-1-one", "2-methyl-", "2-Cyclopenten-1-one", 
    "3-methyl-", "1-Butanol", "2(3H)-Furanone", "5-methyl-", 
    "2(5H)-Furanone 2(3H)-Furanone", "5-butyldihydro-", 
    "2(3H)-Furanone", "5-hexyldihydro-", "2(3H)-Furanone", 
    "5-heptyldihydro-", "Linalool/3", "7- dimethyl-1,6-octadien-3-ol", 
    "α-Pinene", "Benzonitrile", "Pyrrole", "Pyridine Indole", 
    "3-methyl-", "5,10-Diethoxy-2,3,7,8-tetrahydro-1H,6H-dipyrrolo[1,2-α:1′,2′-δ]pyrazine", 
    "Dimethyl sulfone", "Dimethyl trisulphide", "1H-indole, Benzoic acid/Benzaldehyde", 
    "Benzeneacetaldehyde", "Phenol", "2-methyl-", "p-Cresol/4-methylphenol", 
    "Benzophenone", "Benzothiazole"]

wooding = [
    "Dodecanoic acid", "Tetradecanoic acid/Myristic Acid", 
    "Pentadecanoic acid", "Heptadecanoic acid 9,12-Octadecadienoic acid (Z,Z)-", 
    "Octanal", "2-Undecanone", "1-Octanol/Octanol/Isooctanol", 
    "1-Nonanol", "Octadecanol", "1-eicosanol", "ethanol", "2-(2-ethoxyethoxy)-", 
    "ethanol", "2-(dodecyloxy)-", "1", "octanol", "2-butyl", "1-heptanol", 
    "6-methyl-", "hexadecen-1-ol", "trans-9-", 
    "Butyrolactone,2,6,10,15,19,23-hexamethyl-2,6,10,14,18,22-tetracosahexaene (squalene)", 
    "cyclooctatetraene,naphthalene,5-ethyl-1,2,3,4—tetrahydro,cyclobutylamine", 
    "benzonitrile", "3,5-dimethyl-,pentadecane,2-methyl-hexadecane", "3-methyl", 
    "Hexadecane", "2,6,10,14-tetramethyl-", "Octane", "1,1’-oxybis-", 
    "4-cyanocyclohexane,Methyl salicylate", "acetic acid", 
    "octyl ester", "octadecanoicacid", "2,3, dihydroxypropyl ester", 
    "benzene butanoic acidgamma-oxo-", "ethyl ester", 
    "Isopropyl Palmitate 1,2-Benzenedicarboxylic acid", 
    "bis(2-methylpropyl) ester,octyl acrylate", "benzaldehyde", 
    "4-methyl-Benzenemethanol", "α,α-dimethyl-", "phenanthrene", "2,6-Diisopropylnaphthalene"
]

martin = [
    "Benzoic acid", "n- decanoic acid", "xylene (downregulated)", "3-carene (downregulated)"
]

compounds = roodt + wooding + martin
compounds = list(set(compounds))

# %%
len(compounds)
# Out:
# 128

# %%
cass = {}

# %%
for i, compound in enumerate(compounds):
    time.sleep(1)
    try:
        out = cirpy.resolve(compound, "cas")
    except:
        out = None
    cass[compound] = out

# %%
cass_re = {}
for key, values in cass.items():
    if values is None:
        cass_re[key] = values
    elif isinstance(values, list):
        cass_re[key] = ", ".join(values)
        
    else:
        cass_re[key] = values

# %%
pd.DataFrame({
    "Name": cass_re.keys(), "cas": cass_re.values()
}).to_excel("./results/summary_cas.xlsx")

# %%
time.sleep(1) 
cirpy.resolve("formic acid", "cas")
# Out:
# ['15907-03-6', '64-18-6', '7056-83-9', '8006-93-7', '82069-14-5']

# %%
cirpy.resolve("octadecanol", "cas")
# Out:
# ['68911-61-5',
#  '112-92-5',
#  '193766-48-2',
#  '8014-37-7',
#  '8032-19-7',
#  '8032-21-1',
#  '8034-90-0']

# %%
# Get chemical hierarchical names

# %%
# CAS  Cirpy
# input can be CASID: '288-36-8', or name "formic acid"
# output can be "stdinchikey", "cas"
# Out:
# InChIKey=CSCPPACGZOOCGX-UHFFFAOYSA-N

# %%
cirpy.resolve("15907-03-6", "stdinchikey")
# Out:
# 'InChIKey=BDAGIHXWWSANSR-UHFFFAOYSA-N'

# %%
# only M
# cas_list = [
#"methyl ester, [2r-[2.a.(2e,6e),3.a.]-", "2- decanone", "octane, 1,1’-oxybis-", "cyclopent-4-ene-1,3-dione", "4- hydroxybenzoic acid", "methyltridecanoic acid", "12,15-octadecadiynoic acid", "dihydroxypropyl ester", "octanal decanal", "6- methyl-", "benzoic acid", "2-(2-dodecoxyethoxy) ethanol", "butyl octanoate", "2-methyl-1-propanol", "ethanol, 2-(dodecyloxy)-, 1", "homomenthylsalicylate", "phenyl ester", "1-methyl-bis(1,2,4)-triazole-5,1\' nonanal", "2- trifluoroacetoxypentadecane propanoic acid, 2-methyl-", "5-octadecene", "methyl ester 1-methyl hexyl acetate", "3-benzoylmethyl-3- hydroxy-5-nitro-2-indolinone", "1h-indole", "2- butanol", "heptanedioic acid", "1- octanol", "patchouli ethanol", "4-ethyl-3- heptene", "2- methylheptane", "(e)-2- undecenal (e)-2-heptenal", "4- octene", "nonalactone", "9-octadecenoic acid", "n,n-diethyl-3-methylbenzamide (deet) n,n-bis(2-hydroxyethyl)dodecanamide", "acetate 4 hexen-1-ol", "1- chlorononane", "β-pinene", "2- methyl-", "ethyl tetradecanoate", "2-pentanone 4-methyl-2-pentanone", "6,7-diethyl- 1,2,3,4-tetrahydro-1,1,4,4-tetramethyl- naphthalene", "1,2,3- triethyl 2- hydroxypropane- 1,2,3 tricarboxylate", "hexadecen-1-ol, trans-9-", "dodecyl tetradec-9- enoate", "1,3-didecyl- benzene", "2-undecanone", "9- hexadecanoic acid", "3-decen-1-ol", "1-methyl- 1-p-tolylethyl ester, 2-methyl-", "cyclohexanol, 5-methyl-2-(1-methylethyl)-"
#]
# only D
cas_list = [
 "formic acid, butyl ester", "hexadecane, 3-methyl-", "decane, 2,5,9-trimethyl-", "tert-butylpentamethyldisiloxane", "dodecane, 2,7,10-trimethyl-", "glutarimide", "1-butanamine, n-butyl-", "ethanone, 1,1\'-(1,4-phenylene)bis-", "thiazolidine, 2-ethyl-", "4-vinyl-imidazole", "2,5-di-tert-butyl-1,4-benzoquinone", "cyclopentane, butyl-", "à-d-xylofuranoside, methyl 2,5-di-o-methyl-", "2,4,6-trimethyl-1-nonene", "1,3-dioxolane, 2-heptyl-", "thiophene, tetrahydro-2-methyl-", "propanoic acid, anhydride", "cystine", "2(3h)-furanone, dihydro-4-methyl-", "5,9-undecadien-2-one, 6,10-dimethyl-, (e)-", "phorone", "silane, triethoxypentyl-", "1h-pyrrole, 2-methyl-", "(r)-(-)-2-amino-1-propanol", "pentane, 3-ethyl-2,3-dimethyl-", "octane, 1,1\'-oxybis-", "methane, isocyanato-", "acetic acid, 1,1-dimethylethyl ester", "2,5-cyclohexadiene-1,4-dione, 2,5-bis(1,1-dimethylpropyl)-", "4-[1,3]dioxolan-2-yl-3,4-dimethyl-cyclohex-2-enone", "pentadecanal-", "3-tetradecene, (z)-", "disiloxane, 1,3-diethyl-1,1,3,3,-tetramethyl-"
]

# %%
out = []
for i in cas_list:
    out_= cirpy.resolve(i, 'stdinchikey')
    out.append(out_)

# %%
# only D
[re.sub("InChIKey=", "", i) if i is not None else "NA" for i in out]
# Out:
# ['NMJJFJNHVMGPGM-UHFFFAOYSA-N',
#  'WWPCLIMUTNKTDY-UHFFFAOYSA-N',
#  'YKAQOUURBLPHIN-UHFFFAOYSA-N',
#  'KDJUMPQFOPXSMM-UHFFFAOYSA-N',
#  'JCJGCZBSINPZAJ-UHFFFAOYSA-N',
#  'KNCYXPMJDCCGSJ-UHFFFAOYSA-N',
#  'PSBKYMODPYHLAW-UHFFFAOYSA-N',
#  'SKBBQSLSGRSQAJ-UHFFFAOYSA-N',
#  'SZLVYXIKAAFTFY-UHFFFAOYSA-N',
#  'MHQZDNQHLGFBRN-UHFFFAOYSA-N',
#  'ZZYASVWWDLJXIM-UHFFFAOYSA-N',
#  'ZAGHKONXGGSVDV-UHFFFAOYSA-N',
#  'NA',
#  'QFMQAIUZMMQKTB-UHFFFAOYSA-N',
#  'LWJBQKKNODYJEI-UHFFFAOYSA-N',
#  'AJPGNQYBSTXCJE-UHFFFAOYSA-N',
#  'WYVAMUWZEOHJOQ-UHFFFAOYSA-N',
#  'LEVWYRKDKASIDU-IMJSIDKUSA-N',
#  'ALZLTHLQMAFAPA-UHFFFAOYSA-N',
#  'HNZUNIKWNYHEJJ-FMIVXFBMSA-N',
#  'MTZWHHIREPJPTG-UHFFFAOYSA-N',
#  'USDCVUMAPHIAPQ-UHFFFAOYSA-N',
#  'TVCXVUHHCUYLGX-UHFFFAOYSA-N',
#  'BKMMTJMQCTUHRP-GSVOUGTGSA-N',
#  'MMASVVOQIKCFJZ-UHFFFAOYSA-N',
#  'NKJOXAZJBOMXID-UHFFFAOYSA-N',
#  'HAMGRBXTJNITHG-UHFFFAOYSA-N',
#  'WMOVHXAZOJBABW-UHFFFAOYSA-N',
#  'DHXFOYLEDAOQRR-UHFFFAOYSA-N',
#  'VRMKWKXBLAKJNX-UHFFFAOYSA-N',
#  'XGQJZNCFDLXSIJ-UHFFFAOYSA-N',
#  'QKTFNIWYLYTNIS-ALCCZGGFSA-N',
#  'XODWWDLLPURTOQ-UHFFFAOYSA-N']

# %%
# only M
[re.sub("InChIKey=", "", i) if i is not None else "NA" for i in out]
# Out:
# ['NA',
#  'ZAJNGDIORYACQU-UHFFFAOYSA-N',
#  'NKJOXAZJBOMXID-UHFFFAOYSA-N',
#  'MCFZBCCYOPSZLG-UHFFFAOYSA-N',
#  'FJKROLUGYXJWQN-UHFFFAOYSA-N',
#  'FZUUHEZQCQGYNX-UHFFFAOYSA-N',
#  'VSLXDLSYRQJCDS-UHFFFAOYSA-N',
#  'NA',
#  'KBCMEMOHSAQTJR-UHFFFAOYSA-N',
#  'NA',
#  'WPYMKLBDIGXBTP-UHFFFAOYSA-N',
#  'AZLWQVJVINEILY-UHFFFAOYSA-N',
#  'PSXNDMJWRZYVTM-UHFFFAOYSA-N',
#  'ZXEKIIBDNHEJCQ-UHFFFAOYSA-N',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'NA',
#  'YIYQJOMDMPTKEL-UHFFFAOYSA-N',
#  'NA',
#  'QJCFCSBNMAZVSW-UHFFFAOYSA-N',
#  'SIKJAQJRHWYJAI-UHFFFAOYSA-N',
#  'BTANRVKWQNVYAZ-UHFFFAOYSA-N',
#  'WLJVNTCWHIRURA-UHFFFAOYSA-N',
#  'KBPLFHHGFOOTCA-UHFFFAOYSA-N',
#  'NA',
#  'UEXWGMADXSUAIL-UHFFFAOYSA-N',
#  'JVSWJIKNEAIKJW-UHFFFAOYSA-N',
#  'NCPYHILPADPUON-YBDLDTQUSA-N',
#  'IRUCBBFNLDIMIK-UHFFFAOYSA-N',
#  'FTXUQEKXCJSWMO-UHFFFAOYSA-N',
#  'ZQPPMHVWECSIRJ-UHFFFAOYSA-N',
#  'NA',
#  'PEGXQQQLTCYZDF-UHFFFAOYSA-N',
#  'RKAMCQVGHFRILV-UHFFFAOYSA-N',
#  'NA',
#  'NA',
#  'MMKRHZKQPFCLLS-UHFFFAOYSA-N',
#  'APJPTUTVZLXLDF-UHFFFAOYSA-N',
#  'ZCGWNQXAIAWRRA-UHFFFAOYSA-N',
#  'DOOTYTYQINUNNV-UHFFFAOYSA-N',
#  'LBIYNOAMNIKVKF-BQYQJAHWSA-N',
#  'BNVVXPRRISYSOG-UHFFFAOYSA-N',
#  'AUCYVPAWNAGPDL-UHFFFAOYSA-N',
#  'KYWIYKKSMDLRDC-UHFFFAOYSA-N',
#  'NA',
#  'MTIJDFJGPCJFKE-UHFFFAOYSA-N',
#  'NA',
#  'NOOLISFMXDJSKH-UHFFFAOYSA-N']

# %%
out
# Out:
# ['InChIKey=HCRBXQFHJMCTLF-UHFFFAOYSA-N',
#  'InChIKey=LOPWRLYXRMQJBE-UHFFFAOYSA-N',
#  'InChIKey=NEHSXGJRXINMIY-UHFFFAOYSA-N',
#  None,
#  None,
#  'InChIKey=CHGXUMHYPKPHMB-UHFFFAOYSA-N',
#  'InChIKey=WFDSCHJVWDKDFK-UHFFFAOYSA-N',
#  None,
#  None,
#  'InChIKey=UNJNVKPKKZTPPR-OUKQBFOZSA-N',
#  'InChIKey=WNXJIVFYUVYPPR-UHFFFAOYSA-N',
#  'InChIKey=LLHKCFNBLRBOGN-UHFFFAOYSA-N',
#  None,
#  'InChIKey=QTSGWCNIPVKLSF-UHFFFAOYSA-N',
#  'InChIKey=MQYKLMFGPTZTLN-SEYXRHQNSA-N',
#  None,
#  'InChIKey=VCXVRGHERCHZLW-UHFFFAOYSA-N',
#  'InChIKey=LKOVPWSSZFDYPG-UHFFFAOYSA-N',
#  None,
#  'InChIKey=AXISYYRBXTVTFY-UHFFFAOYSA-N']

# %%
name_cas["inchikey"] = out

# %%
name_cas.to_csv("./results/name_cas_inchikey_dict.csv", index = False)
